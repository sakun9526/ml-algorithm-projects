# %%
pip install pandas
pip install numpy
pip install matplotlib
pip install seaborn
# Out:
#   Cell In[24], line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('CarPrice_Dataset.csv')

# %%
# Rows and columns
df.shape

# %%
 # List column names
df.columns

# %%
# Show first 5 rows
df.head()
# Out:
#    id  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0   1          3      gas        std        two  convertible        rwd
# 1   2          3      gas        std        two  convertible        rwd
# 2   3          1      gas        std        two    hatchback        rwd
# 3   4          2      gas        std       four        sedan        fwd
# 4   5          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8  ...         130        mpfi
# 1          front       88.6      168.8  ...         130        mpfi
# 2          front       94.5      171.2  ...         152        mpfi
# 3          front       99.8      176.6  ...         109        mpfi
# 4          front       99.4      176.6  ...         136        mpfi
#
#    boreratio stroke compressionratio  horsepower peakrpm  citympg  highwaympg  \
# ...

# %%
# Show data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
# Summary statistics
df.describe()
# Out:
#                id   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
#check for missing values
df.isnull().sum()
# Out:
# id                  0
# symboling           0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# Rename column names

df.rename(columns={
    'car_ID': 'id'
}, inplace=True)

# %%
df.head()
# Out:
#    id  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0   1          3      gas        std        two  convertible        rwd
# 1   2          3      gas        std        two  convertible        rwd
# 2   3          1      gas        std        two    hatchback        rwd
# 3   4          2      gas        std       four        sedan        fwd
# 4   5          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8  ...         130        mpfi
# 1          front       88.6      168.8  ...         130        mpfi
# 2          front       94.5      171.2  ...         152        mpfi
# 3          front       99.8      176.6  ...         109        mpfi
# 4          front       99.4      176.6  ...         136        mpfi
#
#    boreratio stroke compressionratio  horsepower peakrpm  citympg  highwaympg  \
# ...

# %%
# Returns the number of unique categories
df['CarName'].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Personal\ml-algorithm-projects\Regression\Car Price Prediction\env\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CarName'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 2
# ...

# %%
#Returns the actual unique values in the column.
df['CarName'].unique()

# %%
#drop car name as it has too many categorical values
df.drop('CarName', axis=1, inplace=True)

# %%
df.head()
# Out:
#    id  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0   1          3      gas        std        two  convertible        rwd
# 1   2          3      gas        std        two  convertible        rwd
# 2   3          1      gas        std        two    hatchback        rwd
# 3   4          2      gas        std       four        sedan        fwd
# 4   5          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8  ...         130        mpfi
# 1          front       88.6      168.8  ...         130        mpfi
# 2          front       94.5      171.2  ...         152        mpfi
# 3          front       99.8      176.6  ...         109        mpfi
# 4          front       99.4      176.6  ...         136        mpfi
#
#    boreratio stroke compressionratio  horsepower peakrpm  citympg  highwaympg  \
# ...

# %%
numberOfUniqueCategories = df['fueltype'].nunique()
actualUniqueValues = df['fueltype'].unique()
valueCountEachCategory = df['fueltype'].value_counts()

print(f" numberOfUniqueCategories {numberOfUniqueCategories} \n\n actualUniqueValues {actualUniqueValues} \n\n valueCountEachCategory {valueCountEachCategory}.")
# Out:
#  numberOfUniqueCategories 2
#
#  actualUniqueValues ['gas' 'diesel']
#
#  valueCountEachCategory fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64.

# %%
df = pd.get_dummies(df, columns=['fueltype'], drop_first=True)

# %%
df.head()
# Out:
#    id  symboling aspiration doornumber      carbody drivewheel enginelocation  \
# 0   1          3        std        two  convertible        rwd          front
# 1   2          3        std        two  convertible        rwd          front
# 2   3          1        std        two    hatchback        rwd          front
# 3   4          2        std       four        sedan        fwd          front
# 4   5          2        std       four        sedan        4wd          front
#
#    wheelbase  carlength  carwidth  ...  fuelsystem  boreratio stroke  \
# 0       88.6      168.8      64.1  ...        mpfi       3.47   2.68
# 1       88.6      168.8      64.1  ...        mpfi       3.47   2.68
# 2       94.5      171.2      65.5  ...        mpfi       2.68   3.47
# 3       99.8      176.6      66.2  ...        mpfi       3.19   3.40
# 4       99.4      176.6      66.4  ...        mpfi       3.19   3.40
#
#   compressionratio  horsepower peakrpm  citympg  highwaympg    price  \
# ...
